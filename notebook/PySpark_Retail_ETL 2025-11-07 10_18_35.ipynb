# %%
df = spark.table("workspace.default.online_retail")
df.show()
# Out:
# +---------+---------+--------------------+--------+------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity| InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+------------+---------+----------+--------------+
# |   536365|   85123A|WHITE HANGING HEA...|       6|12/1/10 8:26|     2.55|     17850|United Kingdom|
# |   536365|    71053| WHITE METAL LANTERN|       6|12/1/10 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84406B|CREAM CUPID HEART...|       8|12/1/10 8:26|     2.75|     17850|United Kingdom|
# |   536365|   84029G|KNITTED UNION FLA...|       6|12/1/10 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84029E|RED WOOLLY HOTTIE...|       6|12/1/10 8:26|     3.39|     17850|United Kingdom|
# |   536365|    22752|SET 7 BABUSHKA NE...|       2|12/1/10 8:26|     7.65|     17850|United Kingdom|
# |   536365|    21730|GLASS STAR FROSTE...|       6|12/1/10 8:26|     4.25|     17850|United Kingdom|
# |   536366|    22633|HAND WARMER UNION...|       6|12/1/10 8:28|     1.85|     17850|United Kingdom|
# |   536366|    22632|HAND WARMER RED P...|       6|12/1/10 8:28|     1.85|     17850|United Kingdom|
# |   536367|    84879|ASSORTED COLOUR B...|      32|12/1/10 8:34|     1.69|     13047|United Kingdom|
# |   536367|    22745|POPPY'S PLAYHOUSE...|       6|12/1/10 8:34|      2.1|     13047|United Kingdom|
# |   536367|    22748|POPPY'S PLAYHOUSE...|       6|12/1/10 8:34|      2.1|     13047|United Kingdom|
# |   536367|    22749|FELTCRAFT PRINCES...|       8|12/1/10 8:34|     3.75|     13047|United Kingdom|
# |   536367|    22310|IVORY KNITTED MUG...|       6|12/1/10 8:34|     1.65|     13047|United Kingdom|
# |   536367|    84969|BOX OF 6 ASSORTED...|       6|12/1/10 8:34|     4.25|     13047|United Kingdom|
# |   536367|    22623|BOX OF VINTAGE JI...|       3|12/1/10 8:34|     4.95|     13047|United Kingdom|
# |   536367|    22622|BOX OF VINTAGE AL...|       2|12/1/10 8:34|     9.95|     13047|United Kingdom|
# |   536367|    21754|HOME BUILDING BLO...|       3|12/1/10 8:34|     5.95|     13047|United Kingdom|
# |   536367|    21755|LOVE BUILDING BLO...|       3|12/1/10 8:34|     5.95|     13047|United Kingdom|
# |   536367|    21777|RECIPE BOX WITH M...|       4|12/1/10 8:34|     7.95|     13047|United Kingdom|
# +---------+---------+--------------------+--------+------------+---------+----------+--------------+
# only showing top 20 rows

# %%
bronze_df = df

# %%
bronze_df.show(5)
bronze_df.printSchema()
# Out:
# +---------+---------+--------------------+--------+------------+---------+----------+--------------+
# |InvoiceNo|StockCode|         Description|Quantity| InvoiceDate|UnitPrice|CustomerID|       Country|
# +---------+---------+--------------------+--------+------------+---------+----------+--------------+
# |   536365|   85123A|WHITE HANGING HEA...|       6|12/1/10 8:26|     2.55|     17850|United Kingdom|
# |   536365|    71053| WHITE METAL LANTERN|       6|12/1/10 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84406B|CREAM CUPID HEART...|       8|12/1/10 8:26|     2.75|     17850|United Kingdom|
# |   536365|   84029G|KNITTED UNION FLA...|       6|12/1/10 8:26|     3.39|     17850|United Kingdom|
# |   536365|   84029E|RED WOOLLY HOTTIE...|       6|12/1/10 8:26|     3.39|     17850|United Kingdom|
# +---------+---------+--------------------+--------+------------+---------+----------+--------------+
# only showing top 5 rows
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: long (nullable = true)
#  |-- InvoiceDate: string (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- CustomerID: long (nullable = true)
#  |-- Country: string (nullable = true)

# %%
bronze_df.write.format("delta").mode("overwrite").saveAsTable("bronze_retail")

# %%
bronze_df.select("InvoiceDate").show(20, truncate=False)
# Out:
# +------------+
# |InvoiceDate |
# +------------+
# |12/1/10 8:26|
# |12/1/10 8:26|
# |12/1/10 8:26|
# |12/1/10 8:26|
# |12/1/10 8:26|
# |12/1/10 8:26|
# |12/1/10 8:26|
# |12/1/10 8:28|
# |12/1/10 8:28|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# |12/1/10 8:34|
# +------------+
# only showing top 20 rows

# %%
bronze_df.columns
# Out:
# ['InvoiceNo',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'InvoiceDate',
#  'UnitPrice',
#  'CustomerID',
#  'Country']

# %%
from pyspark.sql.functions import col, regexp_extract, to_timestamp

# 1) Extract only valid-looking timestamps (keeps rows like 1/4/11 10:00)
pattern = r"^\d{1,2}/\d{1,2}/\d{2} \d{1,2}:\d{2}$"

bronze_clean = (
    bronze_df
    .withColumn("InvoiceDateNorm", regexp_extract(col("InvoiceDate"), pattern, 0))
    .filter(col("InvoiceDateNorm") != "")
)

# 2) Parse using flexible month/day (M,d) — this handles 1/4/11 10:00 and 12/10/11 08:26
silver_final = (
    bronze_clean
    .withColumn("InvoiceDate", to_timestamp(col("InvoiceDateNorm"), "M/d/yy H:mm"))
    .filter(col("CustomerID").isNotNull())
    .filter(col("Quantity") > 0)
    .filter(col("UnitPrice") > 0)
    .select(                       # keep only clean columns for Delta
        "InvoiceNo", "StockCode", "Description",
        "Quantity", "UnitPrice", "CustomerID", "Country",
        "InvoiceDate"
    )
)

# Optional sanity check
silver_final.select("InvoiceDate").show(20, truncate=False)
silver_final.printSchema()
# Out:
# +-------------------+
# |InvoiceDate        |
# +-------------------+
# |2010-12-01 08:26:00|
# |2010-12-01 08:26:00|
# |2010-12-01 08:26:00|
# |2010-12-01 08:26:00|
# |2010-12-01 08:26:00|
# |2010-12-01 08:26:00|
# |2010-12-01 08:26:00|
# |2010-12-01 08:28:00|
# |2010-12-01 08:28:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# |2010-12-01 08:34:00|
# +-------------------+
# only showing top 20 rows
# root
#  |-- InvoiceNo: string (nullable = true)
#  |-- StockCode: string (nullable = true)
#  |-- Description: string (nullable = true)
#  |-- Quantity: long (nullable = true)
#  |-- UnitPrice: double (nullable = true)
#  |-- CustomerID: long (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- InvoiceDate: timestamp (nullable = true)

# %%
# If you want to replace the table:
spark.sql("DROP TABLE IF EXISTS silver_retail")

silver_final.write \
    .format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("silver_retail")

# %%
silver_final.show(30
                  )
# Out:
# +---------+---------+--------------------+--------+---------+----------+--------------+-------------------+
# |InvoiceNo|StockCode|         Description|Quantity|UnitPrice|CustomerID|       Country|        InvoiceDate|
# +---------+---------+--------------------+--------+---------+----------+--------------+-------------------+
# |   536365|   85123A|WHITE HANGING HEA...|       6|     2.55|     17850|United Kingdom|2010-12-01 08:26:00|
# |   536365|    71053| WHITE METAL LANTERN|       6|     3.39|     17850|United Kingdom|2010-12-01 08:26:00|
# |   536365|   84406B|CREAM CUPID HEART...|       8|     2.75|     17850|United Kingdom|2010-12-01 08:26:00|
# |   536365|   84029G|KNITTED UNION FLA...|       6|     3.39|     17850|United Kingdom|2010-12-01 08:26:00|
# |   536365|   84029E|RED WOOLLY HOTTIE...|       6|     3.39|     17850|United Kingdom|2010-12-01 08:26:00|
# |   536365|    22752|SET 7 BABUSHKA NE...|       2|     7.65|     17850|United Kingdom|2010-12-01 08:26:00|
# |   536365|    21730|GLASS STAR FROSTE...|       6|     4.25|     17850|United Kingdom|2010-12-01 08:26:00|
# |   536366|    22633|HAND WARMER UNION...|       6|     1.85|     17850|United Kingdom|2010-12-01 08:28:00|
# |   536366|    22632|HAND WARMER RED P...|       6|     1.85|     17850|United Kingdom|2010-12-01 08:28:00|
# |   536367|    84879|ASSORTED COLOUR B...|      32|     1.69|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    22745|POPPY'S PLAYHOUSE...|       6|      2.1|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    22748|POPPY'S PLAYHOUSE...|       6|      2.1|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    22749|FELTCRAFT PRINCES...|       8|     3.75|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    22310|IVORY KNITTED MUG...|       6|     1.65|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    84969|BOX OF 6 ASSORTED...|       6|     4.25|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    22623|BOX OF VINTAGE JI...|       3|     4.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    22622|BOX OF VINTAGE AL...|       2|     9.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    21754|HOME BUILDING BLO...|       3|     5.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    21755|LOVE BUILDING BLO...|       3|     5.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    21777|RECIPE BOX WITH M...|       4|     7.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536367|    48187| DOORMAT NEW ENGLAND|       4|     7.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536368|    22960|JAM MAKING SET WI...|       6|     4.25|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536368|    22913|RED COAT RACK PAR...|       3|     4.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536368|    22912|YELLOW COAT RACK ...|       3|     4.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536368|    22914|BLUE COAT RACK PA...|       3|     4.95|     13047|United Kingdom|2010-12-01 08:34:00|
# |   536369|    21756|BATH BUILDING BLO...|       3|     5.95|     13047|United Kingdom|2010-12-01 08:35:00|
# |   536370|    22728|ALARM CLOCK BAKEL...|      24|     3.75|     12583|        France|2010-12-01 08:45:00|
# |   536370|    22727|ALARM CLOCK BAKEL...|      24|     3.75|     12583|        France|2010-12-01 08:45:00|
# |   536370|    22726|ALARM CLOCK BAKEL...|      12|     3.75|     12583|        France|2010-12-01 08:45:00|
# |   536370|    21724|PANDA AND BUNNIES...|      12|     0.85|     12583|        France|2010-12-01 08:45:00|
# +---------+---------+--------------------+--------+---------+----------+--------------+-------------------+
# only showing top 30 rows

# %%
from pyspark.sql.functions import sum as _sum

gold_country = (
    silver_final
    .withColumn("Revenue", col("Quantity") * col("UnitPrice"))
    .groupBy("Country")
    .agg(_sum("Revenue").alias("TotalRevenue"))
    .orderBy(col("TotalRevenue").desc())
)

display(gold_country)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Country</th><th>TotalRevenue</th></tr></thead><tbody><tr><td>United Kingdom</td><td>7308391.5540030645</td></tr><tr><td>Netherlands</td><td>285446.34</td></tr><tr><td>EIRE</td><td>265545.8999999985</td></tr><tr><td>Germany</td><td>228867.13999999844</td></tr><tr><td>France</td><td>209024.0499999997</td></tr><tr><td>Australia</td><td>138521.30999999956</td></tr><tr><td>Spain</td><td>61577.10999999997</td></tr><tr><td>Switzerland</td><td>56443.95000000004</td></tr><tr><td>Belgium</td><td>41196.33999999997</td></tr><tr><td>Sweden</td><td>38378.33000000003</td></tr><tr><td>Japan</td><td>37416.37000000001</td></tr><tr><td>Norway</td><td>36165.440000000046</td></tr><tr><td>Portugal</td><td>33439.890000000014</td></tr><tr><td>Finland</td><td>22546.079999999973</td></tr><tr><td>Singapore</td><td>21279.289999999994</td></tr><tr><td>Channel Islands</td><td>20450.439999999962</td></tr><tr><td>Denmark</td><td>18955.339999999997</td></tr><tr><td>Italy</td><td>17483.240000000005</td></tr><tr><td>Cyprus</td><td>13590.379999999994</td></tr><tr><td>Austria</td><td>10198.679999999997</td></tr><tr><td>Poland</td><td>7334.649999999997</td></tr><tr><td>Israel</td><td>7221.689999999999</td></tr><tr><td>Greece</td><td>4760.5199999999995</td></tr><tr><td>Iceland</td><td>4309.999999999997</td></tr><tr><td>Canada</td><td>3666.380000000001</td></tr><tr><td>USA</td><td>3580.3900000000012</td></tr><tr><td>Malta</td><td>2725.59</td></tr><tr><td>Unspecified</td><td>2667.0700000000006</td></tr><tr><td>United Arab Emirates</td><td>1902.2800000000007</td></tr><tr><td>Lebanon</td><td>1693.8800000000003</td></tr><tr><td>Lithuania</td><td>1661.06</td></tr><tr><td>European Community</td><td>1300.2500000000002</td></tr><tr><td>Brazil</td><td>1143.6000000000001</td></tr><tr><td>RSA</td><td>1002.3099999999998</td></tr><tr><td>Czech Republic</td><td>826.7400000000001</td></tr><tr><td>Bahrain</td><td>548.4</td></tr><tr><td>Saudi Arabia</td><td>145.92</td></tr></tbody></table></div>

# %%
gold_customers = (
    silver_final
    .withColumn("Revenue", col("Quantity") * col("UnitPrice"))
    .groupBy("CustomerID")
    .agg(_sum("Revenue").alias("TotalSpent"))
    .orderBy(col("TotalSpent").desc())
    .limit(10)
)

display(gold_customers)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>TotalSpent</th></tr></thead><tbody><tr><td>14646</td><td>280206.01999999984</td></tr><tr><td>18102</td><td>259657.30000000005</td></tr><tr><td>17450</td><td>194550.79000000007</td></tr><tr><td>16446</td><td>168472.5</td></tr><tr><td>14911</td><td>143825.05999999944</td></tr><tr><td>12415</td><td>124914.52999999975</td></tr><tr><td>14156</td><td>117379.6299999998</td></tr><tr><td>17511</td><td>91062.37999999996</td></tr><tr><td>16029</td><td>81024.84000000001</td></tr><tr><td>12346</td><td>77183.6</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import month, year, date_format, col, sum as _sum

gold_monthly = (
    silver_final
    .withColumn("Revenue", col("Quantity") * col("UnitPrice"))
    .withColumn("Year", year("InvoiceDate"))
    .withColumn("Month", month("InvoiceDate"))
    .withColumn("YearMonth", date_format(col("InvoiceDate"), "yyyy-MM"))
    .groupBy("YearMonth")
    .agg(_sum("Revenue").alias("MonthlyRevenue"))
    .orderBy("YearMonth")
)

display(gold_monthly)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YearMonth</th><th>MonthlyRevenue</th></tr></thead><tbody><tr><td>2010-12</td><td>572713.8900000163</td></tr><tr><td>2011-01</td><td>569445.0400000077</td></tr><tr><td>2011-02</td><td>447137.3500000165</td></tr><tr><td>2011-03</td><td>595500.760000013</td></tr><tr><td>2011-04</td><td>469200.3610000132</td></tr><tr><td>2011-05</td><td>678594.5600000018</td></tr><tr><td>2011-06</td><td>661213.6900000116</td></tr><tr><td>2011-07</td><td>600091.0110000141</td></tr><tr><td>2011-08</td><td>645343.900000009</td></tr><tr><td>2011-09</td><td>952838.3819999964</td></tr><tr><td>2011-10</td><td>1039318.7899999822</td></tr><tr><td>2011-11</td><td>1161817.3799999433</td></tr><tr><td>2011-12</td><td>518192.7900000037</td></tr></tbody></table></div>

# %%
spark.sql("DROP TABLE IF EXISTS gold_monthly_revenue")
# Out:
# DataFrame[]

# %%
gold_country.write.format("delta").mode("overwrite").saveAsTable("gold_country_revenue")
gold_customers.write.format("delta").mode("overwrite").saveAsTable("gold_top_customers")
gold_monthly.write.format("delta").mode("overwrite").saveAsTable("gold_monthly_revenue")

# %%
display(gold_country)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Country</th><th>TotalRevenue</th></tr></thead><tbody><tr><td>United Kingdom</td><td>7308391.5540030645</td></tr><tr><td>Netherlands</td><td>285446.34</td></tr><tr><td>EIRE</td><td>265545.8999999985</td></tr><tr><td>Germany</td><td>228867.13999999844</td></tr><tr><td>France</td><td>209024.0499999997</td></tr><tr><td>Australia</td><td>138521.30999999956</td></tr><tr><td>Spain</td><td>61577.10999999997</td></tr><tr><td>Switzerland</td><td>56443.95000000004</td></tr><tr><td>Belgium</td><td>41196.33999999997</td></tr><tr><td>Sweden</td><td>38378.33000000003</td></tr><tr><td>Japan</td><td>37416.37000000001</td></tr><tr><td>Norway</td><td>36165.440000000046</td></tr><tr><td>Portugal</td><td>33439.890000000014</td></tr><tr><td>Finland</td><td>22546.079999999973</td></tr><tr><td>Singapore</td><td>21279.289999999994</td></tr><tr><td>Channel Islands</td><td>20450.439999999962</td></tr><tr><td>Denmark</td><td>18955.339999999997</td></tr><tr><td>Italy</td><td>17483.240000000005</td></tr><tr><td>Cyprus</td><td>13590.379999999994</td></tr><tr><td>Austria</td><td>10198.679999999997</td></tr><tr><td>Poland</td><td>7334.649999999997</td></tr><tr><td>Israel</td><td>7221.689999999999</td></tr><tr><td>Greece</td><td>4760.5199999999995</td></tr><tr><td>Iceland</td><td>4309.999999999997</td></tr><tr><td>Canada</td><td>3666.380000000001</td></tr><tr><td>USA</td><td>3580.3900000000012</td></tr><tr><td>Malta</td><td>2725.59</td></tr><tr><td>Unspecified</td><td>2667.0700000000006</td></tr><tr><td>United Arab Emirates</td><td>1902.2800000000007</td></tr><tr><td>Lebanon</td><td>1693.8800000000003</td></tr><tr><td>Lithuania</td><td>1661.06</td></tr><tr><td>European Community</td><td>1300.2500000000002</td></tr><tr><td>Brazil</td><td>1143.6000000000001</td></tr><tr><td>RSA</td><td>1002.3099999999998</td></tr><tr><td>Czech Republic</td><td>826.7400000000001</td></tr><tr><td>Bahrain</td><td>548.4</td></tr><tr><td>Saudi Arabia</td><td>145.92</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
display(gold_monthly)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>YearMonth</th><th>MonthlyRevenue</th></tr></thead><tbody><tr><td>2010-12</td><td>572713.8900000163</td></tr><tr><td>2011-01</td><td>569445.0400000077</td></tr><tr><td>2011-02</td><td>447137.3500000165</td></tr><tr><td>2011-03</td><td>595500.760000013</td></tr><tr><td>2011-04</td><td>469200.3610000132</td></tr><tr><td>2011-05</td><td>678594.5600000018</td></tr><tr><td>2011-06</td><td>661213.6900000116</td></tr><tr><td>2011-07</td><td>600091.0110000141</td></tr><tr><td>2011-08</td><td>645343.900000009</td></tr><tr><td>2011-09</td><td>952838.3819999964</td></tr><tr><td>2011-10</td><td>1039318.7899999822</td></tr><tr><td>2011-11</td><td>1161817.3799999433</td></tr><tr><td>2011-12</td><td>518192.7900000037</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
display(gold_customers)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>CustomerID</th><th>TotalSpent</th></tr></thead><tbody><tr><td>14646</td><td>280206.01999999984</td></tr><tr><td>18102</td><td>259657.30000000005</td></tr><tr><td>17450</td><td>194550.79000000007</td></tr><tr><td>16446</td><td>168472.5</td></tr><tr><td>14911</td><td>143825.05999999944</td></tr><tr><td>12415</td><td>124914.52999999975</td></tr><tr><td>14156</td><td>117379.6299999998</td></tr><tr><td>17511</td><td>91062.37999999996</td></tr><tr><td>16029</td><td>81024.84000000001</td></tr><tr><td>12346</td><td>77183.6</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
total_revenue = silver_final.selectExpr("sum(Quantity * UnitPrice) as TotalRevenue")
display(total_revenue)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TotalRevenue</th></tr></thead><tbody><tr><td>8911407.904003216</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
total_orders = silver_final.selectExpr("count(distinct InvoiceNo) as TotalOrders")
display(total_orders)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>TotalOrders</th></tr></thead><tbody><tr><td>18532</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
unique_customers = silver_final.selectExpr("count(distinct CustomerID) as UniqueCustomers")
display(unique_customers)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>UniqueCustomers</th></tr></thead><tbody><tr><td>4338</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
from pyspark.sql.functions import sum as _sum, countDistinct

aov = (
    silver_final
    .agg(
        (_sum(col("Quantity") * col("UnitPrice")) / countDistinct("InvoiceNo")).alias("AOV")
    )
)
display(aov)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>AOV</th></tr></thead><tbody><tr><td>480.86595639973945</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %%
from pyspark.sql.functions import count

customer_purchase_counts = (
    silver_final
    .groupBy("CustomerID")
    .agg(count("InvoiceNo").alias("NumPurchases"))
)

returning = customer_purchase_counts.filter("NumPurchases >= 2").count()
total = customer_purchase_counts.count()

returning_pct = (returning / total) * 100
from pyspark.sql import Row

kpi_df = spark.createDataFrame([Row(ReturningCustomerPct=returning_pct)])

display(kpi_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ReturningCustomerPct</th></tr></thead><tbody><tr><td>98.3633010603965</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.
